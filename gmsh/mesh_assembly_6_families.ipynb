# %%
import numpy as np
import gmsh 
import sys

# %% [markdown]
# ### Family Mapping 1/4 assembly

# %%
C=[(0,0)]
E=[(1,0),(0,1),(2,0),(0,2),(3,0),(0,3),(4,0),(0,4),(5,0),(0,5),(6,0),(0,6),(7,0),(0,7),(8,0),(0,8)]
N=[(1,1),(2,1),(1,2),(3,1),(1,3)]
D=[(1,4),(4,1),(1,5),(6,1),(1,6),(7,1),(1,7),(2,2),(7,3),(3,7),(4,4),(6,4),(4,6),(7,4),(4,7),(6,6),(7,6),(6,7),(7,7),(6,3),(3,6)]
F=[(5,1),(1,5),(8,1),(1,8),(3,2),(2,3),(2,6),(6,2),(2,7),(7,2),(5,3),(3,5),(8,3),(3,8),(5,4),(4,5),(8,4),(4,8),(6,5),(5,6),(7,5),(5,7),(8,6),(6,8),(8,7),(7,8)]
FD=[(4,2),(2,4),(4,3),(3,4)]
GT=[(5,2),(8,2),(3,3),(2,5),(5,5),(8,5),(2,8),(5,8),[8,8]]
# IT=[8,8]

# %% [markdown]
# ### Family Mapping full assembly

# %%
E_left=[]
E_full=[]
for X in E:
    E_left.append((X[0],X[1]))
    E_left.append((X[0],16-X[1]))
for X in E_left:
    E_full.append((X[0],X[1]))
    E_full.append((16-X[0],X[1]))
E_full = list(set(E_full))

C_left=[]
C_full=[]
for X in C:
    C_left.append((X[0],X[1]))
    C_left.append((X[0],16-X[1]))
for X in C_left:
    C_full.append((X[0],X[1]))
    C_full.append((16-X[0],X[1]))
C_full = list(set(C_full))

    
N_left=[]
N_full=[]
for X in N:
    N_left.append((X[0],X[1]))
    N_left.append((X[0],16-X[1]))
for X in N_left:
    N_full.append((X[0],X[1]))
    N_full.append((16-X[0],X[1]))
N_full = list(set(N_full))


D_left=[]
D_full=[]
for X in D:
    D_left.append((X[0],X[1]))
    D_left.append((X[0],16-X[1]))
for X in D_left:
    D_full.append((X[0],X[1]))
    D_full.append((16-X[0],X[1]))   
D_full = list(set(D_full))


F_left=[]
F_full=[]
for X in F:
    F_left.append((X[0],X[1]))
    F_left.append((X[0],16-X[1]))
for X in F_left:
    F_full.append((X[0],X[1]))
    F_full.append((16-X[0],X[1]))    
F_full = list(set(F_full))

FD_left=[]
FD_full=[]
for X in FD:
    FD_left.append((X[0],X[1]))
    FD_left.append((X[0],16-X[1]))
for X in FD_left:
    FD_full.append((X[0],X[1]))
    FD_full.append((16-X[0],X[1]))    
FD_full = list(set(FD_full))


GT_left=[]
GT_full=[]
for X in GT:
    GT_left.append((X[0],X[1]))
    GT_left.append((X[0],16-X[1]))
for X in GT_left:
    GT_full.append((X[0],X[1]))
    GT_full.append((16-X[0],X[1]))    
GT_full = list(set(GT_full))

# %% [markdown]
# ### Create Mesh

# %%
gmsh.initialize(sys.argv)
gmsh.model.add("Assembly")

dim = 2
h = 1

pitch = 1.26
r_clad = 0.475
r_fuel = 0.418
r_guide_inner=0.561
r_guide_outer=0.602
r_instru_inner=0.559
r_instru_outer=0.605
dr=2e-1

tag=1
moderator = gmsh.model.occ.addRectangle(-dr/2,dr/2,0,17*pitch+dr,-17*pitch-dr,tag=tag)
tag+=1

C_tag_fuel=[]
E_tag_fuel=[]
N_tag_fuel=[]
D_tag_fuel=[]
F_tag_fuel=[]
FD_tag_fuel=[]
GT_tag_water=[]
IT_tag_water=[]
C_tag_clad=[]
E_tag_clad=[]
N_tag_clad=[]
D_tag_clad=[]
F_tag_clad=[]
FD_tag_clad=[]
GT_tag_clad=[]
IT_tag_clad=[]
C_tag_moderator=[]
E_tag_moderator=[]
N_tag_moderator=[]
D_tag_moderator=[]
F_tag_moderator=[]
FD_tag_moderator=[]
GT_tag_moderator=[]
IT_tag_moderator=[]
moderator_tag=[1]

pos=[-pitch/2,pitch/2]
for x in range(17):
    for y in range(17):
        X=(x,y)
        pos[0]=x*pitch+pitch/2
        pos[1]=y*(-pitch)-pitch/2        
        if X in C_full:
            C_moderator_local = gmsh.model.occ.addRectangle(pos[0]-pitch/2,pos[1]+pitch/2,0,pitch,-pitch,tag=tag)
            C_tag_moderator.append(tag)
            tag += 1
            C_clad = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_clad,r_clad,tag)
            C_tag_clad.append(tag)
            tag += 1
            C_fuel = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_fuel,r_fuel,tag)
            C_tag_fuel.append(tag)
            tag += 1
            gmsh.model.occ.cut([(dim,moderator)],
                    [(dim,C_moderator_local)],
                    removeTool=False)
            gmsh.model.occ.cut([(dim,C_moderator_local)],
                    [(dim,C_clad)],
                    removeTool=False)
            gmsh.model.occ.cut([(dim,C_clad)],
                    [(dim,C_fuel)],
                    removeTool=False)
        if X in E_full:
            E_moderator_local = gmsh.model.occ.addRectangle(pos[0]-pitch/2,pos[1]+pitch/2,0,pitch,-pitch,tag=tag)
            E_tag_moderator.append(tag)
            tag += 1
            E_clad = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_clad,r_clad,tag)
            E_tag_clad.append(tag)
            tag += 1
            E_fuel = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_fuel,r_fuel,tag)
            E_tag_fuel.append(tag)
            tag += 1
            gmsh.model.occ.cut([(dim,moderator)],
                    [(dim,E_moderator_local)],
                    removeTool=False)
            gmsh.model.occ.cut([(dim,E_moderator_local)],
                    [(dim,E_clad)],
                    removeTool=False)
            gmsh.model.occ.cut([(dim,E_clad)],
                    [(dim,E_fuel)],
                    removeTool=False)              
        if X in N_full:                
            N_moderator_local = gmsh.model.occ.addRectangle(pos[0]-pitch/2,pos[1]+pitch/2,0,pitch,-pitch,tag=tag)
            N_tag_moderator.append(tag)
            tag += 1
            N_clad = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_clad,r_clad,tag)
            N_tag_clad.append(tag)
            tag += 1
            N_fuel = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_fuel,r_fuel,tag)
            N_tag_fuel.append(tag)
            tag += 1
            gmsh.model.occ.cut([(dim,moderator)],
                    [(dim,N_moderator_local)],
                    removeTool=False)
            gmsh.model.occ.cut([(dim,N_moderator_local)],
                    [(dim,N_clad)],
                    removeTool=False)
            gmsh.model.occ.cut([(dim,N_clad)],
                    [(dim,N_fuel)],
                    removeTool=False)
        if X in D_full:
            D_moderator_local = gmsh.model.occ.addRectangle(pos[0]-pitch/2,pos[1]+pitch/2,0,pitch,-pitch,tag=tag)
            D_tag_moderator.append(tag)
            tag += 1
            D_clad = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_clad,r_clad,tag)
            D_tag_clad.append(tag)
            tag += 1
            D_fuel = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_fuel,r_fuel,tag)
            D_tag_fuel.append(tag)
            tag += 1
            gmsh.model.occ.cut([(dim,moderator)],
                    [(dim,D_moderator_local)],
                    removeTool=False)
            gmsh.model.occ.cut([(dim,D_moderator_local)],
                    [(dim,D_clad)],
                    removeTool=False)
            gmsh.model.occ.cut([(dim,D_clad)],
                    [(dim,D_fuel)],
                    removeTool=False)
        if X in F_full:
            F_moderator_local = gmsh.model.occ.addRectangle(pos[0]-pitch/2,pos[1]+pitch/2,0,pitch,-pitch,tag=tag)
            F_tag_moderator.append(tag)
            tag += 1
            F_clad = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_clad,r_clad,tag)
            F_tag_clad.append(tag)
            tag += 1
            F_fuel = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_fuel,r_fuel,tag)
            F_tag_fuel.append(tag)
            tag += 1
            gmsh.model.occ.cut([(dim,moderator)],
                    [(dim,F_moderator_local)],
                    removeTool=False)
            gmsh.model.occ.cut([(dim,F_moderator_local)],
                    [(dim,F_clad)],
                    removeTool=False)
            gmsh.model.occ.cut([(dim,F_clad)],
                    [(dim,F_fuel)],
                    removeTool=False)
        if X in FD_full:
            FD_moderator_local = gmsh.model.occ.addRectangle(pos[0]-pitch/2,pos[1]+pitch/2,0,pitch,-pitch,tag=tag)
            FD_tag_moderator.append(tag)
            tag += 1
            FD_clad = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_clad,r_clad,tag)
            FD_tag_clad.append(tag)
            tag += 1
            FD_fuel = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_fuel,r_fuel,tag)
            FD_tag_fuel.append(tag)
            tag += 1
            gmsh.model.occ.cut([(dim,moderator)],
                    [(dim,FD_moderator_local)],
                    removeTool=False)
            gmsh.model.occ.cut([(dim,FD_moderator_local)],
                    [(dim,FD_clad)],
                    removeTool=False)
            gmsh.model.occ.cut([(dim,FD_clad)],
                    [(dim,FD_fuel)],
                    removeTool=False)                                  
        if X in GT_full:
            if X==(8,8):
                IT_moderator_local = gmsh.model.occ.addRectangle(pos[0]-pitch/2,pos[1]+pitch/2,0,pitch,-pitch,tag=tag)
                IT_tag_moderator.append(tag)
                tag += 1            
                IT_tube_clad=gmsh.model.occ.addDisk(pos[0],pos[1],0,r_instru_outer,r_instru_outer,tag)
                IT_tag_clad.append(tag)
                tag += 1
                IT_tube_water = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_instru_inner,r_instru_inner,tag)
                IT_tag_water.append(tag)
                tag += 1
                gmsh.model.occ.cut([(dim,moderator)],
                    [(dim,IT_moderator_local)],
                    removeTool=False)            
                gmsh.model.occ.cut([(dim,IT_moderator_local)],
                    [(dim,IT_tube_clad)],
                    removeTool=False)
                gmsh.model.occ.cut([(dim,IT_tube_clad)],
                    [(dim,IT_tube_water)],
                       removeTool=False) 
            else:
                GT_moderator_local = gmsh.model.occ.addRectangle(pos[0]-pitch/2,pos[1]+pitch/2,0,pitch,-pitch,tag=tag)
                GT_tag_moderator.append(tag)
                tag += 1            
                GT_tube_clad=gmsh.model.occ.addDisk(pos[0],pos[1],0,r_guide_outer,r_guide_outer,tag)
                GT_tag_clad.append(tag)
                tag += 1
                GT_tube_water = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_guide_inner,r_guide_inner,tag)
                GT_tag_water.append(tag)
                tag += 1
                gmsh.model.occ.cut([(dim,moderator)],
                    [(dim,GT_moderator_local)],
                    removeTool=False)            
                gmsh.model.occ.cut([(dim,GT_moderator_local)],
                    [(dim,GT_tube_clad)],
                    removeTool=False)
                gmsh.model.occ.cut([(dim,GT_tube_clad)],
                    [(dim,GT_tube_water)],
                       removeTool=False)
        # if X in IT:
        #     IT_moderator_local = gmsh.model.occ.addRectangle(pos[0]-pitch/2,pos[1]+pitch/2,0,pitch,-pitch,tag=tag)
        #     IT_tag_moderator.append(tag)
        #     tag += 1            
        #     IT_tube_clad=gmsh.model.occ.addDisk(pos[0],pos[1],0,r_instru_outer,r_instru_outer,tag)
        #     IT_tag_clad.append(tag)
        #     tag += 1
        #     IT_tube_water = gmsh.model.occ.addDisk(pos[0],pos[1],0,r_instru_inner,r_instru_inner,tag)
        #     IT_tag_water.append(tag)
        #     tag += 1
        #     gmsh.model.occ.cut([(dim,moderator)],
        #             [(dim,IT_moderator_local)],
        #             removeTool=False)            
        #     gmsh.model.occ.cut([(dim,IT_moderator_local)],
        #             [(dim,IT_tube_clad)],
        #             removeTool=False)
        #     gmsh.model.occ.cut([(dim,IT_tube_clad)],
        #             [(dim,IT_tube_water)],
        #                removeTool=False)
# Out:
# Error   : Unknown mesh format '/Users/pablogarcia44/Library/Jupyter/runtime/kernel-f9aba6c0-ca70-4af9-83e0-e8e837cf0d75.json'
# mat.a=2.2
# mat.a=2.4
# mat.a=2.66667
# mat.a=3
# mat.a=3.4
# mat.a=4
# mat.a=3.4
# mat.a=3
# mat.a=2.66667
# mat.a=2.4
# mat.a=2.66667
# mat.a=2.4
# mat.a=2.66667
# mat.a=3
# mat.a=3.4
# mat.a=4
# mat.a=4.8
# mat.a=6

# %% [markdown]
# ### Cut the water

# %% [markdown]
# cutpoint1 = gmsh.model.occ.addPoint(pitch/2,pitch/2,0.0)
# cutpoint2 = gmsh.model.occ.addPoint(pitch/2,-pitch/2,0.0)
# cutline = gmsh.model.occ.addLine(cutpoint1,cutpoint2)

# %% [markdown]
# ### Add Mesh Field

# %% [markdown]
# gmsh.model.mesh.field.add("Distance", 1)
# gmsh.model.mesh.field.setNumbers(1, "CurvesList", [cutline])
# gmsh.model.mesh.field.setNumber(1, "Sampling", 100)
# gmsh.model.mesh.field.add("Threshold", 2)
# gmsh.model.mesh.field.setNumber(2, "InField", 1)
# gmsh.model.mesh.field.setNumber(2, "SizeMin", h/2)
# gmsh.model.mesh.field.setNumber(2, "SizeMax", h)
# gmsh.model.mesh.field.setNumber(2, "DistMin", h*10)
# gmsh.model.mesh.field.setNumber(2, "DistMax", h*20)
#
# gmsh.model.mesh.field.add("Min", 4)
# gmsh.model.mesh.field.setNumbers(4, "FieldsList", [2])
# gmsh.model.mesh.field.setAsBackgroundMesh(4)

# %% [markdown]
# ### Add Phyisical groups

# %%
gmsh.model.occ.synchronize()

def phys_group(group_tag):
    gmsh.model.addPhysicalGroup(dim,tags=group_tag,name=str(group_tag))

group_tag=[moderator_tag,C_tag_fuel,E_tag_fuel,N_tag_fuel,D_tag_fuel,F_tag_fuel,FD_tag_fuel,GT_tag_water,C_tag_clad,E_tag_clad,N_tag_clad,D_tag_clad,F_tag_clad,FD_tag_clad,GT_tag_clad,C_tag_moderator,E_tag_moderator,N_tag_moderator,D_tag_moderator,F_tag_moderator,FD_tag_moderator,GT_tag_moderator]

for group in group_tag:
    phys_group(group)

# %% [markdown]
# ### Mesh Settings

# %%
# gmsh.model.occ.synchronize()
gmsh.option.setNumber("Mesh.MeshSizeExtendFromBoundary", 0)
gmsh.option.setNumber("Mesh.MeshSizeFromPoints", 0)
gmsh.option.setNumber("Mesh.MeshSizeFromCurvature", 0)
gmsh.option.setNumber("Mesh.MeshSizeMax", h)

# Meshing
# Export Mesh to specified version for OpenSn
gmsh.option.setNumber("Mesh.MshFileVersion",2.2)

#Triangle Mesh
gmsh.option.setNumber("Mesh.Algorithm", 6)

#Quads Mesh
# gmsh.model.mesh.setRecombine(dim,1)
# gmsh.option.setNumber("Mesh.Algorithm", 8)

# %% [markdown]
# ### Generate Mesh

# %%
gmsh.model.mesh.generate(dim)
gmsh.write("Assembly.msh")
gmsh.fltk.run()
gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Line)
# Info    : [ 10%] Meshing curve 7 (Line)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 9 (Ellipse)
# Info    : [ 10%] Meshing curve 10 (Ellipse)
# Info    : [ 10%] Meshing curve 17 (Line)
# Info    : [ 10%] Meshing curve 19 (Ellipse)
# Info    : [ 10%] Meshing curve 20 (Ellipse)
# Info    : [ 10%] Meshing curve 29 (Line)
# Info    : [ 10%] Meshing curve 30 (Line)
# Info    : [ 10%] Meshing curve 31 (Line)
# Info    : [ 10%] Meshing curve 34 (Line)
# Info    : [ 10%] Meshing curve 36 (Ellipse)
# Info    : [ 10%] Meshing curve 37 (Ellipse)
# Info    : [ 10%] Meshing curve 48 (Line)
# Info    : [ 10%] Meshing curve 49 (Line)
# Info    : [ 10%] Meshing curve 50 (Line)
# Info    : [ 10%] Meshing curve 53 (Line)
# Info    : [ 10%] Meshing curve 55 (Ellipse)
# Info    : [ 10%] Meshing curve 56 (Ellipse)
# Info    : [ 10%] Meshing curve 69 (Line)
# Info    : [ 10%] Meshing curve 70 (Line)
# Info    : [ 10%] Meshing curve 71 (Line)
# Info    : [ 10%] Meshing curve 74 (Line)
# Info    : [ 10%] Meshing curve 76 (Ellipse)
# Info    : [ 10%] Meshing curve 77 (Ellipse)
# Info    : [ 10%] Meshing curve 92 (Line)
# Info    : [ 10%] Meshing curve 93 (Line)
# Info    : [ 10%] Meshing curve 94 (Line)
# Info    : [ 10%] Meshing curve 97 (Line)
# Info    : [ 10%] Meshing curve 99 (Ellipse)
# Info    : [ 10%] Meshing curve 100 (Ellipse)
# Info    : [ 10%] Meshing curve 117 (Line)
# Info    : [ 10%] Meshing curve 118 (Line)
# Info    : [ 10%] Meshing curve 119 (Line)
# Info    : [ 10%] Meshing curve 122 (Line)
# Info    : [ 10%] Meshing curve 124 (Ellipse)
# Info    : [ 10%] Meshing curve 125 (Ellipse)
# Info    : [ 10%] Meshing curve 144 (Line)
# Info    : [ 10%] Meshing curve 145 (Line)
# Info    : [ 10%] Meshing curve 146 (Line)
# Info    : [ 10%] Meshing curve 149 (Line)
# Info    : [ 10%] Meshing curve 151 (Ellipse)
# Info    : [ 10%] Meshing curve 152 (Ellipse)
# Info    : [ 10%] Meshing curve 173 (Line)
# Info    : [ 10%] Meshing curve 174 (Line)
# Info    : [ 10%] Meshing curve 175 (Line)
# Info    : [ 10%] Meshing curve 178 (Line)
# Info    : [ 10%] Meshing curve 180 (Ellipse)
# Info    : [ 10%] Meshing curve 181 (Ellipse)
# Info    : [ 10%] Meshing curve 204 (Line)
# Info    : [ 10%] Meshing curve 205 (Line)
# Info    : [ 10%] Meshing curve 206 (Line)
# Info    : [ 10%] Meshing curve 209 (Line)
# Info    : [ 10%] Meshing curve 211 (Ellipse)
# Info    : [ 10%] Meshing curve 212 (Ellipse)
# Info    : [ 10%] Meshing curve 237 (Line)
# Info    : [ 10%] Meshing curve 238 (Line)
# Info    : [ 10%] Meshing curve 239 (Line)
# Info    : [ 10%] Meshing curve 242 (Line)
# Info    : [ 10%] Meshing curve 244 (Ellipse)
# Info    : [ 10%] Meshing curve 245 (Ellipse)
# Info    : [ 10%] Meshing curve 272 (Line)
# Info    : [ 10%] Meshing curve 273 (Line)
# Info    : [ 10%] Meshing curve 274 (Line)
# Info    : [ 10%] Meshing curve 277 (Line)
# Info    : [ 10%] Meshing curve 279 (Ellipse)
# Info    : [ 10%] Meshing curve 280 (Ellipse)
# Info    : [ 10%] Meshing curve 309 (Line)
# Info    : [ 10%] Meshing curve 310 (Line)
# Info    : [ 10%] Meshing curve 311 (Line)
# Info    : [ 10%] Meshing curve 314 (Line)
# Info    : [ 10%] Meshing curve 316 (Ellipse)
# Info    : [ 10%] Meshing curve 317 (Ellipse)
# Info    : [ 10%] Meshing curve 348 (Line)
# Info    : [ 10%] Meshing curve 349 (Line)
# Info    : [ 10%] Meshing curve 350 (Line)
# Info    : [ 10%] Meshing curve 353 (Line)
# Info    : [ 10%] Meshing curve 355 (Ellipse)
# Info    : [ 10%] Meshing curve 356 (Ellipse)
# Info    : [ 10%] Meshing curve 389 (Line)
# Info    : [ 10%] Meshing curve 390 (Line)
# Info    : [ 10%] Meshing curve 391 (Line)
# Info    : [ 10%] Meshing curve 394 (Line)
# Info    : [ 10%] Meshing curve 396 (Ellipse)
# Info    : [ 10%] Meshing curve 397 (Ellipse)
# Info    : [ 10%] Meshing curve 432 (Line)
# Info    : [ 10%] Meshing curve 433 (Line)
# Info    : [ 10%] Meshing curve 434 (Line)
# Info    : [ 10%] Meshing curve 437 (Line)
# Info    : [ 10%] Meshing curve 439 (Ellipse)
# Info    : [ 10%] Meshing curve 440 (Ellipse)
# Info    : [ 10%] Meshing curve 477 (Line)
# Info    : [ 10%] Meshing curve 478 (Line)
# Info    : [ 10%] Meshing curve 479 (Line)
# Info    : [ 10%] Meshing curve 482 (Line)
# Info    : [ 10%] Meshing curve 484 (Ellipse)
# Info    : [ 10%] Meshing curve 485 (Ellipse)
# Info    : [ 10%] Meshing curve 524 (Line)
# Info    : [ 10%] Meshing curve 525 (Line)
# Info    : [ 10%] Meshing curve 526 (Line)
# Info    : [ 10%] Meshing curve 528 (Line)
# Info    : [ 10%] Meshing curve 531 (Ellipse)
# Info    : [ 10%] Meshing curve 532 (Ellipse)
# Info    : [ 10%] Meshing curve 573 (Line)
# Info    : [ 10%] Meshing curve 574 (Line)
# Info    : [ 10%] Meshing curve 575 (Line)
# Info    : [ 10%] Meshing curve 580 (Ellipse)
# Info    : [ 10%] Meshing curve 581 (Ellipse)
# Info    : [ 10%] Meshing curve 623 (Line)
# Info    : [ 10%] Meshing curve 624 (Line)
# Info    : [ 10%] Meshing curve 625 (Line)
# Info    : [ 10%] Meshing curve 626 (Line)
# Info    : [ 10%] Meshing curve 631 (Ellipse)
# Info    : [ 10%] Meshing curve 632 (Ellipse)
# Info    : [ 10%] Meshing curve 674 (Line)
# Info    : [ 10%] Meshing curve 675 (Line)
# Info    : [ 10%] Meshing curve 676 (Line)
# Info    : [ 10%] Meshing curve 677 (Line)
# Info    : [ 10%] Meshing curve 682 (Ellipse)
# Info    : [ 10%] Meshing curve 683 (Ellipse)
# Info    : [ 10%] Meshing curve 725 (Line)
# Info    : [ 10%] Meshing curve 726 (Line)
# Info    : [ 10%] Meshing curve 727 (Line)
# Info    : [ 10%] Meshing curve 728 (Line)
# Info    : [ 10%] Meshing curve 733 (Ellipse)
# Info    : [ 10%] Meshing curve 734 (Ellipse)
# Info    : [ 10%] Meshing curve 776 (Line)
# Info    : [ 10%] Meshing curve 777 (Line)
# Info    : [ 10%] Meshing curve 778 (Line)
# Info    : [ 10%] Meshing curve 779 (Line)
# Info    : [ 10%] Meshing curve 784 (Ellipse)
# Info    : [ 10%] Meshing curve 785 (Ellipse)
# Info    : [ 10%] Meshing curve 827 (Line)
# Info    : [ 10%] Meshing curve 828 (Line)
# Info    : [ 10%] Meshing curve 829 (Line)
# Info    : [ 10%] Meshing curve 830 (Line)
# Info    : [ 10%] Meshing curve 835 (Ellipse)
# Info    : [ 10%] Meshing curve 836 (Ellipse)
# Info    : [ 10%] Meshing curve 878 (Line)
# Info    : [ 10%] Meshing curve 879 (Line)
# Info    : [ 10%] Meshing curve 880 (Line)
# Info    : [ 10%] Meshing curve 881 (Line)
# Info    : [ 10%] Meshing curve 886 (Ellipse)
# Info    : [ 10%] Meshing curve 887 (Ellipse)
# Info    : [ 10%] Meshing curve 929 (Line)
# Info    : [ 10%] Meshing curve 930 (Line)
# Info    : [ 10%] Meshing curve 931 (Line)
# Info    : [ 10%] Meshing curve 932 (Line)
# Info    : [ 10%] Meshing curve 937 (Ellipse)
# Info    : [ 10%] Meshing curve 938 (Ellipse)
# Info    : [ 10%] Meshing curve 980 (Line)
# Info    : [ 10%] Meshing curve 981 (Line)
# Info    : [ 10%] Meshing curve 982 (Line)
# Info    : [ 10%] Meshing curve 983 (Line)
# Info    : [ 10%] Meshing curve 988 (Ellipse)
# Info    : [ 10%] Meshing curve 989 (Ellipse)
# Info    : [ 10%] Meshing curve 1031 (Line)
# Info    : [ 10%] Meshing curve 1032 (Line)
# Info    : [ 10%] Meshing curve 1033 (Line)
# Info    : [ 10%] Meshing curve 1034 (Line)
# Info    : [ 10%] Meshing curve 1039 (Ellipse)
# Info    : [ 10%] Meshing curve 1040 (Ellipse)
# Info    : [ 10%] Meshing curve 1082 (Line)
# Info    : [ 10%] Meshing curve 1083 (Line)
# Info    : [ 10%] Meshing curve 1084 (Line)
# Info    : [ 10%] Meshing curve 1085 (Line)
# Info    : [ 10%] Meshing curve 1090 (Ellipse)
# Info    : [ 10%] Meshing curve 1091 (Ellipse)
# Info    : [ 10%] Meshing curve 1133 (Line)
# Info    : [ 10%] Meshing curve 1134 (Line)
# Info    : [ 10%] Meshing curve 1135 (Line)
# Info    : [ 10%] Meshing curve 1136 (Line)
# Info    : [ 10%] Meshing curve 1141 (Ellipse)
# Info    : [ 10%] Meshing curve 1142 (Ellipse)
# Info    : [ 10%] Meshing curve 1184 (Line)
# Info    : [ 10%] Meshing curve 1185 (Line)
# Info    : [ 10%] Meshing curve 1186 (Line)
# Info    : [ 10%] Meshing curve 1187 (Line)
# Info    : [ 10%] Meshing curve 1192 (Ellipse)
# Info    : [ 10%] Meshing curve 1193 (Ellipse)
# Info    : [ 10%] Meshing curve 1235 (Line)
# Info    : [ 20%] Meshing curve 1236 (Line)
# Info    : [ 20%] Meshing curve 1237 (Line)
# Info    : [ 20%] Meshing curve 1238 (Line)
# Info    : [ 20%] Meshing curve 1243 (Ellipse)
# Info    : [ 20%] Meshing curve 1244 (Ellipse)
# Info    : [ 20%] Meshing curve 1286 (Line)
# Info    : [ 20%] Meshing curve 1287 (Line)
# Info    : [ 20%] Meshing curve 1288 (Line)
# Info    : [ 20%] Meshing curve 1289 (Line)
# Info    : [ 20%] Meshing curve 1294 (Ellipse)
# Info    : [ 20%] Meshing curve 1295 (Ellipse)
# Info    : [ 20%] Meshing curve 1337 (Line)
# Info    : [ 20%] Meshing curve 1338 (Line)
# Info    : [ 20%] Meshing curve 1339 (Line)
# Info    : [ 20%] Meshing curve 1340 (Line)
# Info    : [ 20%] Meshing curve 1345 (Ellipse)
# Info    : [ 20%] Meshing curve 1346 (Ellipse)
# Info    : [ 20%] Meshing curve 1388 (Line)
# Info    : [ 20%] Meshing curve 1389 (Line)
# Info    : [ 20%] Meshing curve 1390 (Line)
# Info    : [ 20%] Meshing curve 1391 (Line)
# Info    : [ 20%] Meshing curve 1396 (Ellipse)
# Info    : [ 20%] Meshing curve 1397 (Ellipse)
# Info    : [ 20%] Meshing curve 1439 (Line)
# Info    : [ 20%] Meshing curve 1440 (Line)
# Info    : [ 20%] Meshing curve 1441 (Line)
# Info    : [ 20%] Meshing curve 1442 (Line)
# Info    : [ 20%] Meshing curve 1447 (Ellipse)
# Info    : [ 20%] Meshing curve 1448 (Ellipse)
# Info    : [ 20%] Meshing curve 1491 (Line)
# Info    : [ 20%] Meshing curve 1492 (Line)
# Info    : [ 20%] Meshing curve 1493 (Line)
# Info    : [ 20%] Meshing curve 1494 (Line)
# Info    : [ 20%] Meshing curve 1496 (Line)
# Info    : [ 20%] Meshing curve 1499 (Ellipse)
# Info    : [ 20%] Meshing curve 1500 (Ellipse)
# Info    : [ 20%] Meshing curve 1544 (Line)
# Info    : [ 20%] Meshing curve 1545 (Line)
# Info    : [ 20%] Meshing curve 1546 (Line)
# Info    : [ 20%] Meshing curve 1551 (Ellipse)
# Info    : [ 20%] Meshing curve 1552 (Ellipse)
# Info    : [ 20%] Meshing curve 1597 (Line)
# Info    : [ 20%] Meshing curve 1598 (Line)
# Info    : [ 20%] Meshing curve 1599 (Line)
# Info    : [ 20%] Meshing curve 1600 (Line)
# Info    : [ 20%] Meshing curve 1605 (Ellipse)
# Info    : [ 20%] Meshing curve 1606 (Ellipse)
# Info    : [ 20%] Meshing curve 1651 (Line)
# Info    : [ 20%] Meshing curve 1652 (Line)
# Info    : [ 20%] Meshing curve 1653 (Line)
# Info    : [ 20%] Meshing curve 1654 (Line)
# Info    : [ 20%] Meshing curve 1659 (Ellipse)
# Info    : [ 20%] Meshing curve 1660 (Ellipse)
# Info    : [ 20%] Meshing curve 1705 (Line)
# Info    : [ 20%] Meshing curve 1706 (Line)
# Info    : [ 20%] Meshing curve 1707 (Line)
# Info    : [ 20%] Meshing curve 1708 (Line)
# Info    : [ 20%] Meshing curve 1713 (Ellipse)
# Info    : [ 20%] Meshing curve 1714 (Ellipse)
# Info    : [ 20%] Meshing curve 1759 (Line)
# Info    : [ 20%] Meshing curve 1760 (Line)
# Info    : [ 20%] Meshing curve 1761 (Line)
# Info    : [ 20%] Meshing curve 1762 (Line)
# Info    : [ 20%] Meshing curve 1767 (Ellipse)
# Info    : [ 20%] Meshing curve 1768 (Ellipse)
# Info    : [ 20%] Meshing curve 1813 (Line)
# Info    : [ 20%] Meshing curve 1814 (Line)
# Info    : [ 20%] Meshing curve 1815 (Line)
# Info    : [ 20%] Meshing curve 1816 (Line)
# Info    : [ 20%] Meshing curve 1821 (Ellipse)
# Info    : [ 20%] Meshing curve 1822 (Ellipse)
# Info    : [ 20%] Meshing curve 1867 (Line)
# Info    : [ 20%] Meshing curve 1868 (Line)
# Info    : [ 20%] Meshing curve 1869 (Line)
# Info    : [ 20%] Meshing curve 1870 (Line)
# Info    : [ 20%] Meshing curve 1875 (Ellipse)
# Info    : [ 20%] Meshing curve 1876 (Ellipse)
# Info    : [ 20%] Meshing curve 1921 (Line)
# Info    : [ 20%] Meshing curve 1922 (Line)
# Info    : [ 20%] Meshing curve 1923 (Line)
# Info    : [ 20%] Meshing curve 1924 (Line)
# Info    : [ 20%] Meshing curve 1929 (Ellipse)
# Info    : [ 20%] Meshing curve 1930 (Ellipse)
# Info    : [ 20%] Meshing curve 1975 (Line)
# Info    : [ 20%] Meshing curve 1976 (Line)
# Info    : [ 20%] Meshing curve 1977 (Line)
# Info    : [ 20%] Meshing curve 1978 (Line)
# Info    : [ 20%] Meshing curve 1983 (Ellipse)
# Info    : [ 20%] Meshing curve 1984 (Ellipse)
# Info    : [ 20%] Meshing curve 2029 (Line)
# Info    : [ 20%] Meshing curve 2030 (Line)
# Info    : [ 20%] Meshing curve 2031 (Line)
# Info    : [ 20%] Meshing curve 2032 (Line)
# Info    : [ 20%] Meshing curve 2037 (Ellipse)
# Info    : [ 20%] Meshing curve 2038 (Ellipse)
# Info    : [ 20%] Meshing curve 2083 (Line)
# Info    : [ 20%] Meshing curve 2084 (Line)
# Info    : [ 20%] Meshing curve 2085 (Line)
# Info    : [ 20%] Meshing curve 2086 (Line)
# Info    : [ 20%] Meshing curve 2091 (Ellipse)
# Info    : [ 20%] Meshing curve 2092 (Ellipse)
# Info    : [ 20%] Meshing curve 2137 (Line)
# Info    : [ 20%] Meshing curve 2138 (Line)
# Info    : [ 20%] Meshing curve 2139 (Line)
# Info    : [ 20%] Meshing curve 2140 (Line)
# Info    : [ 20%] Meshing curve 2145 (Ellipse)
# Info    : [ 20%] Meshing curve 2146 (Ellipse)
# Info    : [ 20%] Meshing curve 2191 (Line)
# Info    : [ 20%] Meshing curve 2192 (Line)
# Info    : [ 20%] Meshing curve 2193 (Line)
# Info    : [ 20%] Meshing curve 2194 (Line)
# Info    : [ 20%] Meshing curve 2199 (Ellipse)
# Info    : [ 20%] Meshing curve 2200 (Ellipse)
# Info    : [ 20%] Meshing curve 2245 (Line)
# Info    : [ 20%] Meshing curve 2246 (Line)
# Info    : [ 20%] Meshing curve 2247 (Line)
# Info    : [ 20%] Meshing curve 2248 (Line)
# Info    : [ 20%] Meshing curve 2253 (Ellipse)
# Info    : [ 20%] Meshing curve 2254 (Ellipse)
# Info    : [ 20%] Meshing curve 2299 (Line)
# Info    : [ 20%] Meshing curve 2300 (Line)
# Info    : [ 20%] Meshing curve 2301 (Line)
# Info    : [ 20%] Meshing curve 2302 (Line)
# Info    : [ 20%] Meshing curve 2307 (Ellipse)
# Info    : [ 20%] Meshing curve 2308 (Ellipse)
# Info    : [ 20%] Meshing curve 2353 (Line)
# Info    : [ 20%] Meshing curve 2354 (Line)
# Info    : [ 20%] Meshing curve 2355 (Line)
# Info    : [ 20%] Meshing curve 2356 (Line)
# Info    : [ 20%] Meshing curve 2361 (Ellipse)
# Info    : [ 20%] Meshing curve 2362 (Ellipse)
# Info    : [ 20%] Meshing curve 2407 (Line)
# Info    : [ 20%] Meshing curve 2408 (Line)
# Info    : [ 20%] Meshing curve 2409 (Line)
# Info    : [ 20%] Meshing curve 2410 (Line)
# Info    : [ 20%] Meshing curve 2412 (Line)
# Info    : [ 20%] Meshing curve 2415 (Ellipse)
# Info    : [ 20%] Meshing curve 2416 (Ellipse)
# Info    : [ 20%] Meshing curve 2462 (Line)
# Info    : [ 20%] Meshing curve 2463 (Line)
# Info    : [ 20%] Meshing curve 2464 (Line)
# Info    : [ 20%] Meshing curve 2469 (Ellipse)
# Info    : [ 20%] Meshing curve 2470 (Ellipse)
# Info    : [ 20%] Meshing curve 2517 (Line)
# Info    : [ 20%] Meshing curve 2518 (Line)
# Info    : [ 20%] Meshing curve 2519 (Line)
# Info    : [ 20%] Meshing curve 2520 (Line)
# Info    : [ 20%] Meshing curve 2525 (Ellipse)
# Info    : [ 20%] Meshing curve 2526 (Ellipse)
# Info    : [ 20%] Meshing curve 2573 (Line)
# Info    : [ 20%] Meshing curve 2574 (Line)
# Info    : [ 20%] Meshing curve 2575 (Line)
# Info    : [ 20%] Meshing curve 2576 (Line)
# Info    : [ 20%] Meshing curve 2581 (Ellipse)
# Info    : [ 20%] Meshing curve 2582 (Ellipse)
# Info    : [ 20%] Meshing curve 2629 (Line)
# Info    : [ 20%] Meshing curve 2630 (Line)
# Info    : [ 20%] Meshing curve 2631 (Line)
# Info    : [ 20%] Meshing curve 2632 (Line)
# Info    : [ 20%] Meshing curve 2637 (Ellipse)
# Info    : [ 20%] Meshing curve 2638 (Ellipse)
# Info    : [ 20%] Meshing curve 2685 (Line)
# Info    : [ 20%] Meshing curve 2686 (Line)
# Info    : [ 20%] Meshing curve 2687 (Line)
# Info    : [ 20%] Meshing curve 2688 (Line)
# Info    : [ 20%] Meshing curve 2693 (Ellipse)
# Info    : [ 20%] Meshing curve 2694 (Ellipse)
# Info    : [ 20%] Meshing curve 2741 (Line)
# Info    : [ 20%] Meshing curve 2742 (Line)
# Info    : [ 20%] Meshing curve 2743 (Line)
# Info    : [ 20%] Meshing curve 2744 (Line)
# Info    : [ 20%] Meshing curve 2749 (Ellipse)
# Info    : [ 20%] Meshing curve 2750 (Ellipse)
# Info    : [ 20%] Meshing curve 2797 (Line)
# Info    : [ 20%] Meshing curve 2798 (Line)
# Info    : [ 20%] Meshing curve 2799 (Line)
# Info    : [ 20%] Meshing curve 2800 (Line)
# Info    : [ 20%] Meshing curve 2805 (Ellipse)
# Info    : [ 20%] Meshing curve 2806 (Ellipse)
# Info    : [ 20%] Meshing curve 2853 (Line)
# Info    : [ 20%] Meshing curve 2854 (Line)
# Info    : [ 20%] Meshing curve 2855 (Line)
# Info    : [ 20%] Meshing curve 2856 (Line)
# Info    : [ 30%] Meshing curve 2861 (Ellipse)
# Info    : [ 30%] Meshing curve 2862 (Ellipse)
# Info    : [ 30%] Meshing curve 2909 (Line)
# Info    : [ 30%] Meshing curve 2910 (Line)
# Info    : [ 30%] Meshing curve 2911 (Line)
# Info    : [ 30%] Meshing curve 2912 (Line)
# Info    : [ 30%] Meshing curve 2917 (Ellipse)
# Info    : [ 30%] Meshing curve 2918 (Ellipse)
# Info    : [ 30%] Meshing curve 2965 (Line)
# Info    : [ 30%] Meshing curve 2966 (Line)
# Info    : [ 30%] Meshing curve 2967 (Line)
# Info    : [ 30%] Meshing curve 2968 (Line)
# Info    : [ 30%] Meshing curve 2973 (Ellipse)
# Info    : [ 30%] Meshing curve 2974 (Ellipse)
# Info    : [ 30%] Meshing curve 3021 (Line)
# Info    : [ 30%] Meshing curve 3022 (Line)
# Info    : [ 30%] Meshing curve 3023 (Line)
# Info    : [ 30%] Meshing curve 3024 (Line)
# Info    : [ 30%] Meshing curve 3029 (Ellipse)
# Info    : [ 30%] Meshing curve 3030 (Ellipse)
# Info    : [ 30%] Meshing curve 3077 (Line)
# Info    : [ 30%] Meshing curve 3078 (Line)
# Info    : [ 30%] Meshing curve 3079 (Line)
# Info    : [ 30%] Meshing curve 3080 (Line)
# Info    : [ 30%] Meshing curve 3085 (Ellipse)
# Info    : [ 30%] Meshing curve 3086 (Ellipse)
# Info    : [ 30%] Meshing curve 3133 (Line)
# Info    : [ 30%] Meshing curve 3134 (Line)
# Info    : [ 30%] Meshing curve 3135 (Line)
# Info    : [ 30%] Meshing curve 3136 (Line)
# Info    : [ 30%] Meshing curve 3141 (Ellipse)
# Info    : [ 30%] Meshing curve 3142 (Ellipse)
# Info    : [ 30%] Meshing curve 4285 (Line)
# Info    : [ 30%] Meshing curve 4286 (Line)
# Info    : [ 30%] Meshing curve 4291 (Ellipse)
# Info    : [ 30%] Meshing curve 4292 (Ellipse)
# Info    : [ 30%] Meshing curve 4341 (Line)
# Info    : [ 30%] Meshing curve 4342 (Line)
# Info    : [ 30%] Meshing curve 4343 (Line)
# Info    : [ 30%] Meshing curve 4344 (Line)
# Info    : [ 30%] Meshing curve 4346 (Line)
# Info    : [ 30%] Meshing curve 4349 (Ellipse)
# Info    : [ 30%] Meshing curve 4350 (Ellipse)
# Info    : [ 30%] Meshing curve 4400 (Line)
# Info    : [ 30%] Meshing curve 4401 (Line)
# Info    : [ 30%] Meshing curve 4402 (Line)
# Info    : [ 30%] Meshing curve 4407 (Ellipse)
# Info    : [ 30%] Meshing curve 4408 (Ellipse)
# Info    : [ 30%] Meshing curve 4459 (Line)
# Info    : [ 30%] Meshing curve 4460 (Line)
# Info    : [ 30%] Meshing curve 4461 (Line)
# Info    : [ 30%] Meshing curve 4462 (Line)
# Info    : [ 30%] Meshing curve 4467 (Ellipse)
# Info    : [ 30%] Meshing curve 4468 (Ellipse)
# Info    : [ 30%] Meshing curve 4519 (Line)
# Info    : [ 30%] Meshing curve 4520 (Line)
# Info    : [ 30%] Meshing curve 4521 (Line)
# Info    : [ 30%] Meshing curve 4522 (Line)
# Info    : [ 30%] Meshing curve 4527 (Ellipse)
# Info    : [ 30%] Meshing curve 4528 (Ellipse)
# Info    : [ 30%] Meshing curve 4579 (Line)
# Info    : [ 30%] Meshing curve 4580 (Line)
# Info    : [ 30%] Meshing curve 4581 (Line)
# Info    : [ 30%] Meshing curve 4582 (Line)
# Info    : [ 30%] Meshing curve 4587 (Ellipse)
# Info    : [ 30%] Meshing curve 4588 (Ellipse)
# Info    : [ 30%] Meshing curve 4639 (Line)
# Info    : [ 40%] Meshing curve 4640 (Line)
# Info    : [ 40%] Meshing curve 4641 (Line)
# Info    : [ 40%] Meshing curve 4642 (Line)
# Info    : [ 40%] Meshing curve 4647 (Ellipse)
# Info    : [ 40%] Meshing curve 4648 (Ellipse)
# Info    : [ 40%] Meshing curve 4699 (Line)
# Info    : [ 40%] Meshing curve 4700 (Line)
# Info    : [ 40%] Meshing curve 4701 (Line)
# Info    : [ 40%] Meshing curve 4702 (Line)
# Info    : [ 40%] Meshing curve 4707 (Ellipse)
# Info    : [ 40%] Meshing curve 4708 (Ellipse)
# Info    : [ 40%] Meshing curve 4759 (Line)
# Info    : [ 40%] Meshing curve 4760 (Line)
# Info    : [ 40%] Meshing curve 4761 (Line)
# Info    : [ 40%] Meshing curve 4762 (Line)
# Info    : [ 40%] Meshing curve 4767 (Ellipse)
# Info    : [ 40%] Meshing curve 4768 (Ellipse)
# Info    : [ 40%] Meshing curve 4819 (Line)
# Info    : [ 40%] Meshing curve 4820 (Line)
# Info    : [ 40%] Meshing curve 4821 (Line)
# Info    : [ 40%] Meshing curve 4822 (Line)
# Info    : [ 40%] Meshing curve 4827 (Ellipse)
# Info    : [ 40%] Meshing curve 4828 (Ellipse)
# Info    : [ 40%] Meshing curve 4879 (Line)
# Info    : [ 40%] Meshing curve 4880 (Line)
# Info    : [ 40%] Meshing curve 4881 (Line)
# Info    : [ 40%] Meshing curve 4882 (Line)
# Info    : [ 40%] Meshing curve 4887 (Ellipse)
# Info    : [ 40%] Meshing curve 4888 (Ellipse)
# Info    : [ 40%] Meshing curve 4939 (Line)
# Info    : [ 40%] Meshing curve 4940 (Line)
# Info    : [ 40%] Meshing curve 4941 (Line)
# Info    : [ 40%] Meshing curve 4942 (Line)
# Info    : [ 40%] Meshing curve 4947 (Ellipse)
# Info    : [ 40%] Meshing curve 4948 (Ellipse)
# Info    : [ 40%] Meshing curve 4999 (Line)
# Info    : [ 40%] Meshing curve 5000 (Line)
# Info    : [ 40%] Meshing curve 5001 (Line)
# Info    : [ 40%] Meshing curve 5002 (Line)
# Info    : [ 40%] Meshing curve 5007 (Ellipse)
# Info    : [ 40%] Meshing curve 5008 (Ellipse)
# Info    : [ 40%] Meshing curve 5059 (Line)
# Info    : [ 40%] Meshing curve 5060 (Line)
# Info    : [ 40%] Meshing curve 5061 (Line)
# Info    : [ 40%] Meshing curve 5062 (Line)
# Info    : [ 40%] Meshing curve 5067 (Ellipse)
# Info    : [ 40%] Meshing curve 5068 (Ellipse)
# Info    : [ 40%] Meshing curve 5119 (Line)
# Info    : [ 40%] Meshing curve 5120 (Line)
# Info    : [ 40%] Meshing curve 5121 (Line)
# Info    : [ 40%] Meshing curve 5122 (Line)
# Info    : [ 40%] Meshing curve 5127 (Ellipse)
# Info    : [ 40%] Meshing curve 5128 (Ellipse)
# Info    : [ 40%] Meshing curve 5179 (Line)
# Info    : [ 40%] Meshing curve 5180 (Line)
# Info    : [ 40%] Meshing curve 5181 (Line)
# Info    : [ 40%] Meshing curve 5182 (Line)
# Info    : [ 40%] Meshing curve 5187 (Ellipse)
# Info    : [ 40%] Meshing curve 5188 (Ellipse)
# Info    : [ 40%] Meshing curve 5239 (Line)
# Info    : [ 40%] Meshing curve 5240 (Line)
# Info    : [ 40%] Meshing curve 5241 (Line)
# Info    : [ 40%] Meshing curve 5242 (Line)
# Info    : [ 40%] Meshing curve 5247 (Ellipse)
# Info    : [ 40%] Meshing curve 5248 (Ellipse)
# Info    : [ 40%] Meshing curve 5299 (Line)
# Info    : [ 40%] Meshing curve 5300 (Line)
# Info    : [ 40%] Meshing curve 5301 (Line)
# Info    : [ 40%] Meshing curve 5302 (Line)
# Info    : [ 40%] Meshing curve 5307 (Ellipse)
# Info    : [ 40%] Meshing curve 5308 (Ellipse)
# Info    : [ 40%] Meshing curve 5359 (Line)
# Info    : [ 40%] Meshing curve 5360 (Line)
# Info    : [ 40%] Meshing curve 5361 (Line)
# Info    : [ 40%] Meshing curve 5362 (Line)
# Info    : [ 40%] Meshing curve 5364 (Line)
# Info    : [ 40%] Meshing curve 5367 (Ellipse)
# Info    : [ 40%] Meshing curve 5368 (Ellipse)
# Info    : [ 40%] Meshing curve 5420 (Line)
# Info    : [ 40%] Meshing curve 5421 (Line)
# Info    : [ 40%] Meshing curve 5422 (Line)
# Info    : [ 40%] Meshing curve 5427 (Ellipse)
# Info    : [ 40%] Meshing curve 5428 (Ellipse)
# Info    : [ 40%] Meshing curve 5481 (Line)
# Info    : [ 40%] Meshing curve 5482 (Line)
# Info    : [ 40%] Meshing curve 5483 (Line)
# Info    : [ 40%] Meshing curve 5484 (Line)
# Info    : [ 40%] Meshing curve 5489 (Ellipse)
# Info    : [ 40%] Meshing curve 5490 (Ellipse)
# Info    : [ 40%] Meshing curve 5543 (Line)
# Info    : [ 40%] Meshing curve 5544 (Line)
# Info    : [ 40%] Meshing curve 5545 (Line)
# Info    : [ 40%] Meshing curve 5546 (Line)
# Info    : [ 40%] Meshing curve 5551 (Ellipse)
# Info    : [ 40%] Meshing curve 5552 (Ellipse)
# Info    : [ 40%] Meshing curve 5605 (Line)
# Info    : [ 40%] Meshing curve 5606 (Line)
# Info    : [ 40%] Meshing curve 5607 (Line)
# Info    : [ 40%] Meshing curve 5608 (Line)
# Info    : [ 40%] Meshing curve 5613 (Ellipse)
# Info    : [ 40%] Meshing curve 5614 (Ellipse)
# Info    : [ 40%] Meshing curve 5667 (Line)
# Info    : [ 40%] Meshing curve 5668 (Line)
# Info    : [ 40%] Meshing curve 5669 (Line)
# Info    : [ 40%] Meshing curve 5670 (Line)
# Info    : [ 40%] Meshing curve 5675 (Ellipse)
# Info    : [ 40%] Meshing curve 5676 (Ellipse)
# Info    : [ 40%] Meshing curve 5729 (Line)
# Info    : [ 40%] Meshing curve 5730 (Line)
# Info    : [ 40%] Meshing curve 5731 (Line)
# Info    : [ 40%] Meshing curve 5732 (Line)
# Info    : [ 40%] Meshing curve 5737 (Ellipse)
# Info    : [ 40%] Meshing curve 5738 (Ellipse)
# Info    : [ 40%] Meshing curve 5791 (Line)
# Info    : [ 40%] Meshing curve 5792 (Line)
# Info    : [ 40%] Meshing curve 5793 (Line)
# Info    : [ 40%] Meshing curve 5794 (Line)
# Info    : [ 40%] Meshing curve 5799 (Ellipse)
# Info    : [ 40%] Meshing curve 5800 (Ellipse)
# Info    : [ 40%] Meshing curve 5853 (Line)
# Info    : [ 40%] Meshing curve 5854 (Line)
# Info    : [ 40%] Meshing curve 5855 (Line)
# Info    : [ 40%] Meshing curve 5856 (Line)
# Info    : [ 40%] Meshing curve 5861 (Ellipse)
# Info    : [ 40%] Meshing curve 5862 (Ellipse)
# Info    : [ 40%] Meshing curve 5915 (Line)
# Info    : [ 40%] Meshing curve 5916 (Line)
# Info    : [ 40%] Meshing curve 5917 (Line)
# Info    : [ 40%] Meshing curve 5918 (Line)
# Info    : [ 40%] Meshing curve 5923 (Ellipse)
# Info    : [ 40%] Meshing curve 5924 (Ellipse)
# Info    : [ 40%] Meshing curve 5977 (Line)
# Info    : [ 40%] Meshing curve 5978 (Line)
# Info    : [ 40%] Meshing curve 5979 (Line)
# Info    : [ 40%] Meshing curve 5980 (Line)
# Info    : [ 40%] Meshing curve 5985 (Ellipse)
# Info    : [ 40%] Meshing curve 5986 (Ellipse)
# Info    : [ 40%] Meshing curve 6039 (Line)
# Info    : [ 40%] Meshing curve 6040 (Line)
# Info    : [ 40%] Meshing curve 6041 (Line)
# Info    : [ 40%] Meshing curve 6042 (Line)
# Info    : [ 40%] Meshing curve 6047 (Ellipse)
# Info    : [ 40%] Meshing curve 6048 (Ellipse)
# Info    : [ 40%] Meshing curve 6101 (Line)
# Info    : [ 40%] Meshing curve 6102 (Line)
# Info    : [ 40%] Meshing curve 6103 (Line)
# Info    : [ 40%] Meshing curve 6104 (Line)
# Info    : [ 40%] Meshing curve 6109 (Ellipse)
# Info    : [ 40%] Meshing curve 6110 (Ellipse)
# Info    : [ 40%] Meshing curve 6163 (Line)
# Info    : [ 40%] Meshing curve 6164 (Line)
# Info    : [ 40%] Meshing curve 6165 (Line)
# Info    : [ 40%] Meshing curve 6166 (Line)
# Info    : [ 40%] Meshing curve 6171 (Ellipse)
# Info    : [ 40%] Meshing curve 6172 (Ellipse)
# Info    : [ 40%] Meshing curve 6225 (Line)
# Info    : [ 40%] Meshing curve 6226 (Line)
# Info    : [ 40%] Meshing curve 6227 (Line)
# Info    : [ 40%] Meshing curve 6228 (Line)
# Info    : [ 40%] Meshing curve 6233 (Ellipse)
# Info    : [ 40%] Meshing curve 6234 (Ellipse)
# Info    : [ 40%] Meshing curve 6287 (Line)
# Info    : [ 40%] Meshing curve 6288 (Line)
# Info    : [ 40%] Meshing curve 6289 (Line)
# Info    : [ 40%] Meshing curve 6290 (Line)
# Info    : [ 40%] Meshing curve 6295 (Ellipse)
# Info    : [ 40%] Meshing curve 6296 (Ellipse)
# Info    : [ 40%] Meshing curve 6349 (Line)
# Info    : [ 40%] Meshing curve 6350 (Line)
# Info    : [ 40%] Meshing curve 6351 (Line)
# Info    : [ 40%] Meshing curve 6352 (Line)
# Info    : [ 40%] Meshing curve 6357 (Ellipse)
# Info    : [ 40%] Meshing curve 6358 (Ellipse)
# Info    : [ 40%] Meshing curve 6411 (Line)
# Info    : [ 40%] Meshing curve 6412 (Line)
# Info    : [ 40%] Meshing curve 6413 (Line)
# Info    : [ 40%] Meshing curve 6414 (Line)
# Info    : [ 40%] Meshing curve 6416 (Line)
# Info    : [ 40%] Meshing curve 6419 (Ellipse)
# Info    : [ 40%] Meshing curve 6420 (Ellipse)
# Info    : [ 40%] Meshing curve 6474 (Line)
# Info    : [ 40%] Meshing curve 6475 (Line)
# Info    : [ 40%] Meshing curve 6476 (Line)
# Info    : [ 50%] Meshing curve 6481 (Ellipse)
# Info    : [ 50%] Meshing curve 6482 (Ellipse)
# Info    : [ 50%] Meshing curve 6537 (Line)
# Info    : [ 50%] Meshing curve 6538 (Line)
# Info    : [ 50%] Meshing curve 6539 (Line)
# Info    : [ 50%] Meshing curve 6540 (Line)
# Info    : [ 50%] Meshing curve 6545 (Ellipse)
# Info    : [ 50%] Meshing curve 6546 (Ellipse)
# Info    : [ 50%] Meshing curve 6601 (Line)
# Info    : [ 50%] Meshing curve 6602 (Line)
# Info    : [ 50%] Meshing curve 6603 (Line)
# Info    : [ 50%] Meshing curve 6604 (Line)
# Info    : [ 50%] Meshing curve 6609 (Ellipse)
# Info    : [ 60%] Meshing curve 9162 (Line)
# Info    : [ 60%] Meshing curve 9167 (Ellipse)
# Info    : [ 60%] Meshing curve 9168 (Ellipse)
# Info    : [ 60%] Meshing curve 9227 (Line)
# Info    : [ 60%] Meshing curve 9228 (Line)
# Info    : [ 60%] Meshing curve 9229 (Line)
# Info    : [ 60%] Meshing curve 9230 (Line)
# Info    : [ 60%] Meshing curve 9235 (Ellipse)
# Info    : [ 60%] Meshing curve 9236 (Ellipse)
# Info    : [ 60%] Meshing curve 9295 (Line)
# Info    : [ 60%] Meshing curve 9296 (Line)
# Info    : [ 60%] Meshing curve 9297 (Line)
# Info    : [ 60%] Meshing curve 9298 (Line)
# Info    : [ 60%] Meshing curve 9303 (Ellipse)
# Info    : [ 60%] Meshing curve 9304 (Ellipse)
# Info    : [ 60%] Meshing curve 9363 (Line)
# Info    : [ 60%] Meshing curve 9364 (Line)
# Info    : [ 60%] Meshing curve 9365 (Line)
# Info    : [ 60%] Meshing curve 9366 (Line)
# Info    : [ 60%] Meshing curve 9371 (Ellipse)
# Info    : [ 60%] Meshing curve 9372 (Ellipse)
# Info    : [ 60%] Meshing curve 9431 (Line)
# Info    : [ 60%] Meshing curve 9432 (Line)
# Info    : [ 60%] Meshing curve 9433 (Line)
# Info    : [ 60%] Meshing curve 9434 (Line)
# Info    : [ 60%] Meshing curve 9439 (Ellipse)
# Info    : [ 60%] Meshing curve 9440 (Ellipse)
# Info    : [ 60%] Meshing curve 9499 (Line)
# Info    : [ 60%] Meshing curve 9500 (Line)
# Info    : [ 60%] Meshing curve 9501 (Line)
# Info    : [ 60%] Meshing curve 9502 (Line)
# Info    : [ 60%] Meshing curve 9507 (Ellipse)
# Info    : [ 60%] Meshing curve 9508 (Ellipse)
# Info    : [ 60%] Meshing curve 9567 (Line)
# Info    : [ 60%] Meshing curve 9568 (Line)
# Info    : [ 60%] Meshing curve 9569 (Line)
# Info    : [ 60%] Meshing curve 9570 (Line)
# Info    : [ 60%] Meshing curve 9575 (Ellipse)
# Info    : [ 60%] Meshing curve 9576 (Ellipse)
# Info    : [ 60%] Meshing curve 9635 (Line)
# Info    : [ 60%] Meshing curve 9636 (Line)
# Info    : [ 60%] Meshing curve 9637 (Line)
# Info    : [ 60%] Meshing curve 9638 (Line)
# Info    : [ 60%] Meshing curve 9643 (Ellipse)
# Info    : [ 60%] Meshing curve 9644 (Ellipse)
# Info    : [ 60%] Meshing curve 9703 (Line)
# Info    : [ 60%] Meshing curve 9704 (Line)
# Info    : [ 60%] Meshing curve 9705 (Line)
# Info    : [ 60%] Meshing curve 9706 (Line)
# Info    : [ 60%] Meshing curve 9711 (Ellipse)
# Info    : [ 60%] Meshing curve 9712 (Ellipse)
# Info    : [ 60%] Meshing curve 9771 (Line)
# Info    : [ 60%] Meshing curve 9772 (Line)
# Info    : [ 60%] Meshing curve 9773 (Line)
# Info    : [ 60%] Meshing curve 9774 (Line)
# Info    : [ 60%] Meshing curve 9776 (Line)
# Info    : [ 60%] Meshing curve 9779 (Ellipse)
(Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 646 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 647 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 648 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 649 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 650 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 651 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 652 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 653 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 654 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 655 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 656 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 657 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 658 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 659 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 660 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 661 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 662 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 663 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 664 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 665 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 666 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 667 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 668 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 669 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 670 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 671 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 672 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 673 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 674 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 675 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 676 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 677 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 678 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 679 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 680 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 681 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 682 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 683 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 684 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 685 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 686 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 687 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 688 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 689 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 690 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 691 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 692 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 693 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 694 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 695 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 696 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 697 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 698 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 699 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 700 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 701 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 702 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 703 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 704 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 705 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 706 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 707 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 708 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 709 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 710 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 711 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 712 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 713 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 714 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 715 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 716 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 717 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 718 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 719 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 720 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 721 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 722 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 723 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 724 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 725 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 726 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 727 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 728 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 729 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 730 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 731 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 732 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 733 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 734 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 735 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 736 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 737 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 738 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 739 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 740 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 741 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 742 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 743 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 744 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 745 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 746 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 747 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 748 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 749 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 750 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 751 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 752 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 753 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 754 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 755 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 756 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 757 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 758 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 759 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 760 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 761 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 762 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 763 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 764 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 765 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 766 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 767 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 768 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 769 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 770 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 771 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 772 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 773 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 774 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 775 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 776 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 777 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 778 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 779 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 780 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 781 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 782 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 783 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 784 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 785 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 786 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 787 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 788 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 789 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 790 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 791 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 792 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 793 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 794 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 795 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 796 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 797 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 798 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 799 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 800 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 801 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 802 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 803 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 804 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 805 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 806 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 807 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 808 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 809 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 810 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 811 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 812 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 813 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 814 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 815 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 816 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 817 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 818 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 819 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 820 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 821 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 822 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 823 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 824 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 825 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 826 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 827 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 828 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 829 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 830 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 831 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 832 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 833 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 834 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 835 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 836 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 837 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 838 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 839 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 840 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 841 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 842 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 843 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 844 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 845 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 846 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 847 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 848 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 849 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 850 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 851 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 852 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 853 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 854 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 855 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 856 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 857 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 858 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 859 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 860 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 861 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 862 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 863 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 864 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 865 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 866 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 867 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 868 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 869 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 870 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 871 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 872 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 873 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 874 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 875 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 876 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 877 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 878 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 879 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 880 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.193089s, CPU 0.194548s)
# Info    : 6959 nodes 19268 elements
# Info    : Writing 'Assembly.msh'...
# Info    : Done writing 'Assembly.msh'
# -------------------------------------------------------
# Version       : 4.13.1
# License       : GNU General Public License
# Build OS      : MacOSX-sdk
# Build date    : 20240524
# Build host    : gmsh.info
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blas[petsc] Blossom Cgns DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack Lapack[petsc] MathEx[contrib] Med Mesh Metis[contrib] Mmg Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom PETSc Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] TouchBar Untangle Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.4.0
# PETSc version : 3.15.0 (real arithmtic)
# OCC version   : 7.7.2
# MED version   : 4.1.0
# Packaged by   : geuzaine
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------
